# %% [markdown]
# # 1. Accuracy by carries

# %%
from plot_results import *

# %%
experiment_name = 'iccm2019'
operators_list = ['add', 'subtract']

# %%
plot_mean_accuracy_by_carries(experiment_name, operators_list, mode='show')
plot_mean_accuracy_by_carries(experiment_name, operators_list, mode='save')
plot_mean_accuracy_by_carries(experiment_name, operators_list, mode='save', file_format='png')

# %% [markdown]
# # 2. Mean solving solving time by carries

# %%
from plot_results import *

# %%
experiment_name = 'iccm2019'
operators_list = ['add', 'subtract']

# %%
plot_mean_mean_solving_time_by_carries(experiment_name, operators_list, ylim_range=(0,12), rm_carry_outlier=True, rm_carry_outlier_method='iqr', mode='show')
plot_mean_mean_solving_time_by_carries(experiment_name, operators_list, ylim_range=(0,12), rm_carry_outlier=True, rm_carry_outlier_method='iqr', mode='save')
plot_mean_mean_solving_time_by_carries(experiment_name, operators_list, ylim_range=(0,12), rm_carry_outlier=True, rm_carry_outlier_method='iqr', mode='save', file_format='png')

# %%
plot_mean_mean_solving_time_by_carries(experiment_name, operators_list, ylim_range=(2,12), rm_carry_outlier=True, rm_carry_outlier_method='iqr', mode='show')
plot_mean_mean_solving_time_by_carries(experiment_name, operators_list, ylim_range=(2,12), rm_carry_outlier=True, rm_carry_outlier_method='iqr', mode='save')
plot_mean_mean_solving_time_by_carries(experiment_name, operators_list, ylim_range=(2,12), rm_carry_outlier=True, rm_carry_outlier_method='iqr', mode='save', file_format='png')
