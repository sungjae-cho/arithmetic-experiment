# %%
from plot_results import *

# %% [markdown]
# # 1. Accuracy

# %% [markdown]
# ## 1.1. Total accuacy

# %%
from plot_results import *

# %%
total_accuracy = get_accuracy(groupby_operator=False, groupby_carries=False)
total_accuracy
# Out:
# 0.9161764705882353

# %%
type(total_accuracy)
# Out:
# numpy.float64

# %% [markdown]
# ## 1.2. Accuracy by operator

# %%
from plot_results import *

# %%
accuracy_by_operator = get_accuracy(groupby_operator=True, groupby_carries=False)
accuracy_by_operator
# Out:
# operator
# add         0.970769
# divide      0.940385
# modulo      0.947500
# multiply    0.804762
# subtract    0.934615
# Name: correct, dtype: float64

# %%
type(accuracy_by_operator)
# Out:
# pandas.core.series.Series

# %%
accuracy_by_operator['add'], accuracy_by_operator['subtract'], accuracy_by_operator['multiply'], accuracy_by_operator['divide'], accuracy_by_operator['modulo']
# Out:
# (0.9707692307692307,
#  0.9346153846153846,
#  0.8047619047619048,
#  0.9403846153846154,
#  0.9475)

# %%
type(accuracy_by_operator['add'])
# Out:
# numpy.float64

# %%
plot_accuracy_by_operator(mode='show')
plot_accuracy_by_operator(mode='save')
plot_accuracy_by_operator(mode='save', file_format='png')

# %% [markdown]
# ## 1.3. Accuracy by carries

# %%
from plot_results import *

# %%
accuracy_by_carries = get_accuracy(groupby_operator=True, groupby_carries=True)
accuracy_by_carries
# Out:
# operator  carries
# add       0          1.000000
#           1          0.984615
#           2          0.953846
#           3          0.984615
#           4          0.930769
# divide    0          0.946154
#           1          0.938462
#           2          0.961538
#           3          0.915385
# modulo    0          0.910000
#           1          0.960000
#           2          0.960000
#           3          0.960000
# multiply  0          0.914286
#           1          0.857143
#           2          0.814286
#           3          0.814286
#           4          0.842857
#           5          0.771429
#           6          0.757143
#           8          0.728571
#           12         0.742857
# subtract  0          0.984615
#           1          0.961538
#           2          0.923077
#           3          0.869231
# Name: correct, dtype: float64

# %%
plot_accuracy_by_carries(mode='show')
plot_accuracy_by_carries(mode='save')
plot_accuracy_by_carries(mode='save', file_format='png')

# %% [markdown]
# # 2. Mean solving time

# %% [markdown]
# ## 2.1. Total mean solving time

# %%
from plot_results import *

# %%
get_mean_solving_time(groupby_operator=False, groupby_carries=False)
# Out:
# 15.276144485294116

# %% [markdown]
# ## 2.2. Mean solving time by operator

# %%
from plot_results import *

# %%
get_mean_solving_time(groupby_operator=True, groupby_carries=False)
# Out:
# operator
# add          7.604238
# divide       8.692492
# modulo      14.395570
# multiply    31.377041
# subtract    12.620188
# Name: solving_time, dtype: float64

# %%
plot_mean_solving_time_by_operator(mode='show')
plot_mean_solving_time_by_operator(mode='save')
plot_mean_solving_time_by_operator(mode='save', file_format='png')

# %% [markdown]
# ## 2.3. Mean solving solving time by carries

# %%
from plot_results import *

# %%
get_mean_solving_time(groupby_operator=True, groupby_carries=True)
# Out:
# operator  carries
# add       0           3.655915
#           1           5.891392
#           2           8.151023
#           3          10.022315
#           4          10.300546
# divide    0           7.045385
#           1           8.298385
#           2           8.967969
#           3          10.458231
# modulo    0           8.935540
#           1          15.445010
#           2          16.881250
#           3          16.320480
# multiply  0          24.198000
#           1          30.520371
#           2          26.043500
#           3          28.683343
#           4          31.127900
#           5          36.128329
#           6          32.497071
#           8          39.898371
#           12         33.296486
# subtract  0           5.185231
#           1           9.490608
#           2          14.789692
#           3          21.015223
# Name: solving_time, dtype: float64

# %%
plot_mean_solving_time_by_carries(mode='show')
plot_mean_solving_time_by_carries(mode='save')
plot_mean_solving_time_by_carries(mode='save', file_format='png')

# %% [markdown]
# # 3. Solving time: Box plot

# %% [markdown]
# ## 3.1. Solving time by operator

# %%
from plot_results import *

# %%
plot_solving_time_by_operator(mode='show')
plot_solving_time_by_operator(mode='save')
plot_solving_time_by_operator(mode='save', file_format='png')

# %% [markdown]
# ## 3.2. Solving time by carries

# %%
from plot_results import *

# %%
plot_solving_time_by_carries(mode='show')
plot_solving_time_by_carries(mode='save')
plot_solving_time_by_carries(mode='save', file_format='png')

# %% [markdown]
# # Plot the rest of all

# %%
from plot_results import *

# %%
plot_all(mode='show')
plot_all(mode='save')
plot_all(mode='save', file_format='png')
