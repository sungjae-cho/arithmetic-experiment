# %%
from plot_results import *

# %% [markdown]
# # Accuracy

# %%
get_accuracy(groupby_operator=False, groupby_carries=False)
# Out:
# 0.9111940298507463

# %%
get_accuracy(groupby_operator=True, groupby_carries=False)
# Out:
# operator
# add         0.964000
# divide      0.970000
# modulo      0.950000
# multiply    0.835556
# subtract    0.921429
# Name: correct, dtype: float64

# %%
get_accuracy(groupby_operator=True, groupby_carries=True)
# Out:
# operator  carries
# add       0          1.000000
#           1          0.980000
#           2          0.960000
#           3          1.000000
#           4          0.880000
# divide    0          0.960000
#           1          0.980000
#           2          0.980000
#           3          0.960000
# modulo    0          0.925000
#           1          0.925000
#           2          1.000000
#           3          0.950000
# multiply  0          0.980000
#           1          0.880000
#           2          0.840000
#           3          0.820000
#           4          0.880000
#           5          0.760000
#           6          0.780000
#           8          0.740000
#           12         0.840000
# subtract  0          0.971429
#           1          0.957143
#           2          0.914286
#           3          0.842857
# Name: correct, dtype: float64

# %% [markdown]
# # Mean solving time

# %%
get_mean_solving_time(groupby_operator=False, groupby_carries=False)
# Out:
# 16.050147761194026

# %%
get_mean_solving_time(groupby_operator=True, groupby_carries=False)
# Out:
# operator
# add          6.250956
# divide       6.040150
# modulo      13.864356
# multiply    28.504411
# subtract    13.182668
# Name: solving_time, dtype: float64

# %%
get_mean_solving_time(groupby_operator=True, groupby_carries=True)
# Out:
# operator  carries
# add       0           2.598120
#           1           4.809820
#           2           7.510580
#           3           7.629320
#           4           8.706940
# divide    0           5.288980
#           1           7.121540
#           2           6.639800
#           3           5.110280
# modulo    0           9.061400
#           1          13.198450
#           2          19.150725
#           3          14.046850
# multiply  0          18.684960
#           1          23.552660
#           2          24.975620
#           3          26.023620
#           4          30.362000
#           5          34.397900
#           6          30.750280
#           8          35.061280
#           12         32.731380
# subtract  0           5.951157
#           1          10.549257
#           2          13.057957
#           3          23.172300
# Name: solving_time, dtype: float64

# %% [markdown]
# # Plot the rest of all

# %%
plot_all(mode='show')

# %%
plot_all(mode='save')
