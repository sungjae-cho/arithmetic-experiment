# %%
from plot_results import *

# %% [markdown]
# # 1. Accuracy

# %% [markdown]
# ## 1.1. Total accuacy

# %%
from plot_results import *

# %%
total_accuracy = get_accuracy(groupby_operator=False, groupby_carries=False)
total_accuracy
# Out:
# 0.9227031131359149

# %%
type(total_accuracy)
# Out:
# numpy.float64

# %% [markdown]
# ## 1.2. Accuracy by operator

# %%
from plot_results import *

# %%
accuracy_by_operator = get_accuracy(groupby_operator=True, groupby_carries=False)
accuracy_by_operator
# Out:
# operator
# add         0.960000
# divide      0.925000
# modulo      0.912500
# multiply    0.877441
# subtract    0.940000
# Name: correct, dtype: float64

# %%
type(accuracy_by_operator)
# Out:
# pandas.core.series.Series

# %%
accuracy_by_operator['add'], accuracy_by_operator['subtract'], accuracy_by_operator['multiply'], accuracy_by_operator['divide'], accuracy_by_operator['modulo']
# Out:
# (0.96, 0.94, 0.8774410774410775, 0.925, 0.9125)

# %%
type(accuracy_by_operator['add'])
# Out:
# numpy.float64

# %%
plot_accuracy_by_operator(mode='show')
plot_accuracy_by_operator(mode='save')
plot_accuracy_by_operator(mode='save', file_format='png')

# %%
plot_mean_accuracy_by_operator(mode='show')
plot_mean_accuracy_by_operator(mode='save')
plot_mean_accuracy_by_operator(mode='save', file_format='png')

# %% [markdown]
# ## 1.3. Accuracy by carries

# %%
from plot_results import *

# %%
accuracy_by_carries = get_accuracy(groupby_operator=True, groupby_carries=True)
accuracy_by_carries
# Out:
# operator  carries
# add       0          0.996667
#           1          0.983333
#           2          0.943333
#           3          0.956667
#           4          0.920000
# divide    0          0.906667
#           1          0.923333
#           2          0.933333
#           3          0.936667
# modulo    0          0.890000
#           1          0.930000
#           2          0.920000
#           3          0.910000
# multiply  0          0.987879
#           1          0.921212
#           2          0.896970
#           3          0.884848
#           4          0.896970
#           5          0.824242
#           6          0.812121
#           8          0.830303
#           12         0.842424
# subtract  0          0.990000
#           1          0.973333
#           2          0.926667
#           3          0.870000
# Name: correct, dtype: float64

# %%
plot_accuracy_by_carries(mode='show')
plot_accuracy_by_carries(mode='save')
plot_accuracy_by_carries(mode='save', file_format='png')

# %%
plot_mean_accuracy_by_carries(mode='show')
plot_mean_accuracy_by_carries(mode='save')
plot_mean_accuracy_by_carries(mode='save', file_format='png')

# %% [markdown]
# # 2. Mean solving time

# %% [markdown]
# ## 2.1. Total mean solving time

# %%
from plot_results import *

# %%
get_mean_solving_time(groupby_operator=False, groupby_carries=False)
# Out:
# (14.937316932422172, 17.667452871082983)

# %% [markdown]
# ## 2.2. Mean solving time by operator

# %%
from plot_results import *

# %%
get_mean_solving_time(groupby_operator=True, groupby_carries=False)
# Out:
# (operator
#  add          8.318561
#  divide       9.308048
#  modulo      15.650303
#  multiply    28.642894
#  subtract    11.166394
#  Name: solving_time, dtype: float64, operator
#  add          6.780811
#  divide      14.968542
#  modulo      16.682990
#  multiply    23.951077
#  subtract    10.499810
#  Name: solving_time, dtype: float64)

# %%
plot_mean_solving_time_by_operator(mode='show')
plot_mean_solving_time_by_operator(mode='save')
plot_mean_solving_time_by_operator(mode='save', file_format='png')

# %%
plot_mean_mean_solving_time_by_operator(mode='show')
plot_mean_mean_solving_time_by_operator(mode='save')
plot_mean_mean_solving_time_by_operator(mode='save', file_format='png')

# %% [markdown]
# ## 2.3. Mean solving solving time by carries

# %%
from plot_results import *

# %%
get_mean_solving_time(groupby_operator=True, groupby_carries=True)
# Out:
# (operator  carries
#  add       0           3.801607
#            1           6.111123
#            2           9.472870
#            3          10.488467
#            4          11.718737
#  divide    0           8.636340
#            1           9.029610
#            2          10.797030
#            3           8.769213
#  modulo    0          10.911507
#            1          15.830067
#            2          17.668407
#            3          18.191230
#  multiply  0          17.737836
#            1          25.584073
#            2          24.770952
#            3          26.143000
#            4          29.901630
#            5          32.917636
#            6          29.471055
#            8          40.743255
#            12         30.516606
#  subtract  0           4.481773
#            1           8.926370
#            2          13.347860
#            3          17.909573
#  Name: solving_time, dtype: float64, operator  carries
#  add       0           3.457596
# ...

# %%
plot_mean_solving_time_by_carries(mode='show')
plot_mean_solving_time_by_carries(mode='save')
plot_mean_solving_time_by_carries(mode='save', file_format='png')

# %%
plot_mean_mean_solving_time_by_carries(mode='show')
plot_mean_mean_solving_time_by_carries(mode='save')
plot_mean_mean_solving_time_by_carries(mode='save', file_format='png')

# %% [markdown]
# # 3. Solving time: Box plot

# %% [markdown]
# ## 3.1. Solving time by operator

# %%
from plot_results import *

# %%
boxplot_mean_solving_time_by_operator(mode='show')
boxplot_mean_solving_time_by_operator(mode='save')
boxplot_mean_solving_time_by_operator(mode='save', file_format='png')

# %% [markdown]
# ## 3.2. Solving time by carries

# %%
from plot_results import *

# %%
boxplot_mean_solving_time_by_carries(mode='show')
boxplot_mean_solving_time_by_carries(mode='save')
boxplot_mean_solving_time_by_carries(mode='save', file_format='png')

# %% [markdown]
# # Plot the rest of all

# %%
from plot_results import *

# %%
plot_all_mst_by_problems(mode='show')
plot_all_mst_by_problems(mode='save')
plot_all_mst_by_problems(mode='save', file_format='png')
