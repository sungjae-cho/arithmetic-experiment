# %% [markdown]
# # 1. Mean solving time by operator

# %%
from plot_results_cogsci2019 import *

# %%
experiment_name = 'cogsci2019'

# %%
plot_mean_mean_solving_time_by_operator(experiment_name, mode='show')
plot_mean_mean_solving_time_by_operator(experiment_name, mode='save')
plot_mean_mean_solving_time_by_operator(experiment_name, mode='save', file_format='png')

# %% [markdown]
# # 2.1. Accuracy by carries

# %%
from plot_results_cogsci2019 import *

# %%
experiment_name = 'cogsci2019'
operators_list = ['add', 'subtract', 'multiply', 'divide', 'modulo']

# %%
plot_mean_accuracy_by_carries(experiment_name, operators_list, mode='show')
plot_mean_accuracy_by_carries(experiment_name, operators_list, mode='save')
plot_mean_accuracy_by_carries(experiment_name, operators_list, mode='save', file_format='png')

# %% [markdown]
# # 2.2. Mean solving solving time by carries

# %%
from plot_results_cogsci2019 import *

# %%
experiment_name = 'cogsci2019'

# %%
operators_list = ['add']
plot_mean_mean_solving_time_by_carries(experiment_name, operators_list, rm_carry_outlier=False, mode='show')
plot_mean_mean_solving_time_by_carries(experiment_name, operators_list, rm_carry_outlier=False, mode='save')
plot_mean_mean_solving_time_by_carries(experiment_name, operators_list, rm_carry_outlier=False, mode='save', file_format='png')

# %%
operators_list = ['subtract']
plot_mean_mean_solving_time_by_carries(experiment_name, operators_list, rm_carry_outlier=False, mode='show')
plot_mean_mean_solving_time_by_carries(experiment_name, operators_list, rm_carry_outlier=False, mode='save')
plot_mean_mean_solving_time_by_carries(experiment_name, operators_list, rm_carry_outlier=False, mode='save', file_format='png')

# %%
operators_list = ['multiply']
plot_mean_mean_solving_time_by_carries(experiment_name, operators_list, rm_carry_outlier=False, mode='show')
plot_mean_mean_solving_time_by_carries(experiment_name, operators_list, rm_carry_outlier=False, mode='save')
plot_mean_mean_solving_time_by_carries(experiment_name, operators_list, rm_carry_outlier=False, mode='save', file_format='png')

# %%
operators_list = ['divide']
plot_mean_mean_solving_time_by_carries(experiment_name, operators_list, rm_carry_outlier=False, mode='show')
plot_mean_mean_solving_time_by_carries(experiment_name, operators_list, rm_carry_outlier=False, mode='save')
plot_mean_mean_solving_time_by_carries(experiment_name, operators_list, rm_carry_outlier=False, mode='save', file_format='png')

# %%
operators_list = ['modulo']
plot_mean_mean_solving_time_by_carries(experiment_name, operators_list, rm_carry_outlier=False, mode='show')
plot_mean_mean_solving_time_by_carries(experiment_name, operators_list, rm_carry_outlier=False, mode='save')
plot_mean_mean_solving_time_by_carries(experiment_name, operators_list, rm_carry_outlier=False, mode='save', file_format='png')
